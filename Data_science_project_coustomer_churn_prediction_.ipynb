# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerana-RK/Prerana-RK/blob/main/Data_science_project_coustomer_churn_prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1 = df.drop('customerID',axis=1).copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df1['TotalCharges'][3826]
# Out:
# ' '

# %% [markdown]
# Even though we don't see any missing values, when we look at the data, total charges feature has missing values.

# %%
df1.iloc[3826]
# Out:
# gender                             Male
# SeniorCitizen                         0
# Partner                             Yes
# Dependents                          Yes
# tenure                                0
# PhoneService                        Yes
# MultipleLines                       Yes
# InternetService                      No
# OnlineSecurity      No internet service
# OnlineBackup        No internet service
# DeviceProtection    No internet service
# TechSupport         No internet service
# StreamingTV         No internet service
# StreamingMovies     No internet service
# Contract                       Two year
# PaperlessBilling                     No
# PaymentMethod              Mailed check
# MonthlyCharges                    25.35
# TotalCharges
# Churn                                No
# Name: 3826, dtype: object

# %% [markdown]
# We will make the correct coding to define misisng values.

# %%
df1['TotalCharges'] = df1['TotalCharges'].apply(lambda x : x if x!= ' ' else np.nan).astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df1['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %% [markdown]
# Even thoguh data has missing values, models which we will use in this study can handle the missing values internally.

# %%
df1['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
y = df1['Churn'].value_counts(normalize=True)*100

# %%
y
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
plt.hist(x=y,bins=3)
# Out:
# (array([1., 0., 1.]),
#  array([26.53698708, 42.17899569, 57.82100431, 73.46301292]),
#  <BarContainer object of 3 artists>)

# %%
x = pd.DataFrame(y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data=x)

# %%
plt.hist(x=df1['Churn'],bins=3)
# Out:
# (array([5174.,    0., 1869.]),
#  array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(x=y,bins=3)
# Out:
# (array([1., 0., 1.]),
#  array([26.53698708, 42.17899569, 57.82100431, 73.46301292]),
#  <BarContainer object of 3 artists>)

# %%
df1.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
gender_ration = df1['gender'].value_counts(normalize=True)*100

# %%
gender_ration
# Out:
# gender
# Male      50.47565
# Female    49.52435
# Name: proportion, dtype: float64

# %%
plt.pie(data=df1,x=gender_ration,autopct='%1.1f%%')
plt.title('Gender_ratio')
labels = ['male','female']
plt.legend(labels)
plt.show()

# %%
sns.pairplot(data=df1)

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %% [markdown]
# hitmap for missing values

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
colores = {'Yes':'red','No':'blue'}
palettes = {0:'red',1:'blue'}

for i, predictor in enumerate(df1.drop(columns=['Churn','TotalCharges','MonthlyCharges','tenure'])):
  plt.figure(i,figsize=(5,3))
  sns.countplot(data=df1,x=predictor,hue='Churn',palette=colores)
  plt.title(predictor)
  plt.show()

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
sns.countplot(x='Churn',data=df1)
plt.title('churn distrubution')
plt.show()

# %%
sns.countplot(x='gender',hue='Churn',data=df1)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.histplot(data=df, x='tenure', hue='Churn', bins=30, kde=True)
plt.title('Tenure vs Churn')
plt.show()

# %%
# Charges Distribution by Churn
sns.boxplot(x='Churn',y='MonthlyCharges',data=df1)
plt.title('Monthlycharge vs Churn')
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df1 = df1.drop(['Dependents','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport',
                'StreamingMovies','Contract','PaperlessBilling'],axis=1)

# %%
df1
# Out:
#       gender  SeniorCitizen Partner  tenure PhoneService StreamingTV  \
# 0     Female              0     Yes       1           No          No
# 1       Male              0      No      34          Yes          No
# 2       Male              0      No       2          Yes          No
# 3       Male              0      No      45           No          No
# 4     Female              0      No       2          Yes          No
# ...      ...            ...     ...     ...          ...         ...
# 7038    Male              0     Yes      24          Yes         Yes
# 7039  Female              0     Yes      72          Yes         Yes
# 7040  Female              0     Yes      11           No          No
# 7041    Male              1     Yes       4          Yes          No
# 7042    Male              0      No      66          Yes         Yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0              Electronic check           29.85         29.85    No
# ...

# %%
df1.drop('PaymentMethod',axis=1)
# Out:
#       gender  SeniorCitizen Partner  tenure PhoneService StreamingTV  \
# 0     Female              0     Yes       1           No          No
# 1       Male              0      No      34          Yes          No
# 2       Male              0      No       2          Yes          No
# 3       Male              0      No      45           No          No
# 4     Female              0      No       2          Yes          No
# ...      ...            ...     ...     ...          ...         ...
# 7038    Male              0     Yes      24          Yes         Yes
# 7039  Female              0     Yes      72          Yes         Yes
# 7040  Female              0     Yes      11           No          No
# 7041    Male              1     Yes       4          Yes          No
# 7042    Male              0      No      66          Yes         Yes
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# ...

# %%
df1.drop('TotalCharges',axis=1,inplace=True)

# %%
df1
# Out:
#       gender  SeniorCitizen Partner  tenure PhoneService StreamingTV  \
# 0     Female              0     Yes       1           No          No
# 1       Male              0      No      34          Yes          No
# 2       Male              0      No       2          Yes          No
# 3       Male              0      No      45           No          No
# 4     Female              0      No       2          Yes          No
# ...      ...            ...     ...     ...          ...         ...
# 7038    Male              0     Yes      24          Yes         Yes
# 7039  Female              0     Yes      72          Yes         Yes
# 7040  Female              0     Yes      11           No          No
# 7041    Male              1     Yes       4          Yes          No
# 7042    Male              0      No      66          Yes         Yes
#
#                   PaymentMethod  MonthlyCharges Churn
# 0              Electronic check           29.85    No
# ...

# %%
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = pd.get_dummies(df1,columns=['gender','Partner','PhoneService','StreamingTV','PaymentMethod'])

# %%
df1
# Out:
#       SeniorCitizen  tenure  MonthlyCharges Churn  gender_Female  gender_Male  \
# 0                 0       1           29.85    No           True        False
# 1                 0      34           56.95    No          False         True
# 2                 0       2           53.85   Yes          False         True
# 3                 0      45           42.30    No          False         True
# 4                 0       2           70.70   Yes           True        False
# ...             ...     ...             ...   ...            ...          ...
# 7038              0      24           84.80    No          False         True
# 7039              0      72          103.20    No           True        False
# 7040              0      11           29.60    No           True        False
# 7041              1       4           74.40   Yes          False         True
# 7042              0      66          105.65    No          False         True
#
# ...

# %% [markdown]
# Model traning the data

# %%
from sklearn.model_selection import train_test_split

# %%
x = df1.drop('Churn',axis=1)
y = df['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_test.head(5)
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  gender_Female  gender_Male  \
# 185               0       1           24.80           True        False
# 2715              0      41           25.25          False         True
# 3825              0      52           19.35           True        False
# 1807              0       1           76.35           True        False
# 132               0      67           50.55          False         True
#
#       Partner_No  Partner_Yes  PhoneService_No  PhoneService_Yes  \
# 185        False         True             True             False
# 2715        True        False            False              True
# 3825       False         True            False              True
# 1807        True        False            False              True
# 132         True        False            False              True
#
#       StreamingTV_No  StreamingTV_No internet service  StreamingTV_Yes  \
# ...

# %% [markdown]
# Train and fit a logistic regression model on the training set.**

# %%
from sklearn.linear_model import LogisticRegression

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SeniorCitizen                            7043 non-null   int64
#  1   tenure                                   7043 non-null   int64
#  2   MonthlyCharges                           7043 non-null   float64
#  3   Churn                                    7043 non-null   object
#  4   gender_Female                            7043 non-null   bool
#  5   gender_Male                              7043 non-null   bool
#  6   Partner_No                               7043 non-null   bool
#  7   Partner_Yes                              7043 non-null   bool
#  8   PhoneService_No                          7043 non-null   bool
#  9   PhoneService_Yes                         7043 non-null   bool
# ...

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prerdict = lr.predict(x_test)

# %%
prerdict
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,prerdict)*100
# Out:
# 79.93374349266446

# %%
confusion_matrix(y_test,prerdict)
# Out:
# array([[1411,  128],
#        [ 296,  278]])

# %%
print(classification_report(y_test,prerdict))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.92      0.87      1539
#          Yes       0.68      0.48      0.57       574
#
#     accuracy                           0.80      2113
#    macro avg       0.76      0.70      0.72      2113
# weighted avg       0.79      0.80      0.79      2113
